# %% [markdown]
# # SALARY PREDICTION BASED ON YEARS OF EXPERIENCE

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
plt.scatter(df[['YearsExperience']],df[['Salary']])
plt.show()

# %%
plt.xlabel("Experience in Years")
plt.ylabel("Salary ")
plt.scatter(df[['YearsExperience']],df[['Salary']])
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['YearsExperience']],df[['Salary']])
# Out:
# LinearRegression()

# %%
plt.xlabel("Experience in Years")
plt.ylabel("Salary ")
plt.scatter(df[['YearsExperience']],df[['Salary']],color='green',marker='+')
plt.plot(df[['YearsExperience']],reg.predict(df[['YearsExperience']]), color='red')
plt.show()

# %%
reg.predict([[7]])
# Out:
# C:\Users\subha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[91941.93644885]])

# %%
reg.coef_
# Out:
# array([[9449.96232146]])

# %%
reg.intercept_
# Out:
# array([25792.20019867])

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df1=pd.read_csv("Salary to predict.csv")

# %%
df1
# Out:
#     YearsExperience
# 0               3.8
# 1               7.5
# 2               9.6
# 3               4.2
# 4               5.2
# 5               5.5
# 6               6.2
# 7               6.4
# 8               6.6
# 9               6.5
# 10             10.3
# 11             14.0

# %%
reg.predict(df1)
# Out:
# array([[ 61702.0570202 ],
#        [ 96666.91760958],
#        [116511.83848464],
#        [ 65482.04194878],
#        [ 74932.00427024],
#        [ 77766.99296667],
#        [ 84381.96659169],
#        [ 86271.95905598],
#        [ 88161.95152027],
#        [ 87216.95528813],
#        [123126.81210966],
#        [158091.67269904]])

# %%
predictions = reg.predict(df1)

# %%
df1['Predicted Salary']=predictions

# %%
df1.to_csv("Predicted Salary.csv")

# %%
df2=pd.read_csv("Predicted Salary.csv", encoding="utf-8")

# %%
df2
# Out:
#     Unnamed: 0  YearsExperience  Predicted Salary
# 0            0              3.8      61702.057020
# 1            1              7.5      96666.917610
# 2            2              9.6     116511.838485
# 3            3              4.2      65482.041949
# 4            4              5.2      74932.004270
# 5            5              5.5      77766.992967
# 6            6              6.2      84381.966592
# 7            7              6.4      86271.959056
# 8            8              6.6      88161.951520
# 9            9              6.5      87216.955288
# 10          10             10.3     123126.812110
# 11          11             14.0     158091.672699

# %%
plt.xlabel("Years if Exp")
plt.ylabel("Salary Expected")
plt.scatter(df2[['YearsExperience']],df2[['Predicted Salary']])
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 reg.coeff_
#
# AttributeError: 'LinearRegression' object has no attribute 'coeff_'
